# %%
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

# %%
img=Image.open("iris.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1275x477 at 0x2A9DE0C22E0>

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
plt.scatter(df['petal_length'],df['petal_width'])# show linear relationship

# %%
plt.scatter(df['sepal_length'],df['sepal_width'])

# %%
plt.scatter(df['petal_length'],df['sepal_width'])

# %%
plt.scatter(df['sepal_length'],df['petal_width'])

# %%
### draw all the graphs

# %%
import seaborn as sns

# %%
sns.pairplot(df,hue='species')# it means with respect to species it form the graph with all parameters

# %%
# first case me setosa ki sepal length kam h sepal width setosa ki sbse jyada h ye hme pta chlta h upr wale graph se

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# ab hm kinhi 2 features ko lekr aage bdenge mtlb 3 mese 2 species ko lekr isme logistic reg lgayaenge ab hm 2 features ko lenge

# %%
df2=df[(df['species']=='setosa')|(df['species']=='versicolor')]# hmne 2 species leli koi se

# %%
df2
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# ..           ...          ...           ...          ...         ...
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor
#
# [100 rows x 5 columns]

# %%
#df2=df.loc[:99]ye secnd method bhi h first two species ko select krne ke liye

# %%
sns.pairplot(df2,hue='species')# ye 2 species ko lekr graph h with all parameters

# %% [markdown]
# # applying logistic regression by considered two species

# %%
from sklearn.model_selection import train_test_split

# %%
#xtrain,xtest,ytrain,ytest=train_test_split(df2.drop('species',axis=1),df2['species'],test_size=0.25,random_state=101)

# %%
#xtrain.info()

# %%
#xtest.info()

# %%
#ytrain.shape

# %%
#ytest.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
#model=LogisticRegression().fit(xtrain,ytrain)

# %%
#ypred=model.predict(xtest)

# %%
#ypred

# %%
#round(model.score(xtest,ytest)*100,2)# gives 100 %

# %%
# now considering other two species and see the percentage of score

# %%
df3=df[(df['species']=='versicolor')|(df['species']=='virginica')]
xtrain3,xtest3,ytrain3,ytest3=train_test_split(df3.drop('species',axis=1),df3['species'],test_size=0.25,random_state=101)
model3=LogisticRegression().fit(xtrain3,ytrain3)
round(model3.score(xtest3,ytest3)*100,2)
# Out:
# 100.0

# %% [markdown]
# # creating confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report# in linear there are error but in logistic there is confusion

# %%
ypred3=model3.predict(xtest3)

# %%
print(confusion_matrix(ypred3,ytest3))
# Out:
# [[15  0]
#  [ 0 10]]

# %%
print(classification_report(ypred3,ytest3))# this shows the classification_report
# Out:
#               precision    recall  f1-score   support
#
#   versicolor       1.00      1.00      1.00        15
#    virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25

# %%
import pandas as pd

# %%
sepallength=eval(input(''))
sepalwidth=eval(input(''))
petallength=eval(input(''))
petalwidth=eval(input(''))
query=pd.DataFrame({
    'sepal_length':[sepallength],
    'sepal_width':[sepalwidth],
    'petal_length':[petallength],
    'petal_width':[petalwidth],
})
# Out:
#  5.1
#  3.1
#  6
#  .5

# %%
query
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.1             6          0.5

# %%
model3.predict(query)[0]
# Out:
# 'virginica'

# %%
## full model completed
