# %%
import requests
from bs4 import BeautifulSoup

# %%
curr_page=1
product='smart phones'
url='https://www.flipkart.com/search?q='

# %%
header2={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
}

# %%
query_url=url + '+'.join(product.split()) + '&page={}'.format(curr_page)# concat string
query_url
# Out:
# 'https://www.flipkart.com/search?q=smart+phones&page=1'

# %%
r=requests.get(query_url,headers=header2)# successfull req
r.status_code
# Out:
# 200

# %%
text=r.text
soup=BeautifulSoup(text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
titles=[i.text for i in soup.find_all('div',{'class':'_4rR01T'})]

# %%
titles
# Out:
# ['realme C20 (Cool Grey, 32 GB)',
#  'realme C21 (Cross Blue, 32 GB)',
#  'realme C21 (Cross Black, 32 GB)',
#  'realme C21 (Cross Black, 64 GB)',
#  'realme C21 (Cross Blue, 64 GB)',
#  'REDMI 9i (Midnight Black, 64 GB)',
#  'POCO M3 (Power Black, 64 GB)',
#  'realme Narzo 30A (Laser Black, 32 GB)',
#  'realme Narzo 30A (Laser Blue, 32 GB)',
#  'realme Narzo 30A (Laser Black, 64 GB)',
#  'POCO M3 (Cool Blue, 64 GB)',
#  'Infinix Smart 5 (Aegean Blue, 32 GB)',
#  'Infinix Smart 5 (7° Purple, 32 GB)',
#  'Infinix Smart 5 (Morandi Green, 32 GB)',
#  'Infinix Smart 5 (Obsidian Black, 32 GB)',
#  'GIONEE Max (Red, 32 GB)',
#  'realme C12 (Power Silver, 32 GB)',
#  'realme C12 (Power Blue, 32 GB)',
#  'REDMI 9 Power (Electric Green, 64 GB)',
#  'REDMI 9i (Nature Green, 64 GB)',
#  'GIONEE Max (Black, 32 GB)',
#  'realme C25 (Watery Blue, 64 GB)',
#  'LG W41 Pro (Laser Blue, 128 GB)',
#  'Infinix Hot 10 (Moonlight Jade, 64 GB)']

# %%
len(titles)
# Out:
# 24

# %%
disc_price=[i.text for i in soup.find_all('div',{'class':'_30jeq3 _1_WHN1'})]
disc_price
# Out:
# ['₹6,799',
#  '₹7,999',
#  '₹7,999',
#  '₹8,999',
#  '₹8,999',
#  '₹7,999',
#  '₹10,999',
#  '₹7,999',
#  '₹7,999',
#  '₹8,999',
#  '₹10,999',
#  '₹6,799',
#  '₹6,799',
#  '₹6,799',
#  '₹6,799',
#  '₹5,499',
#  '₹7,999',
#  '₹7,999',
#  '₹10,499',
#  '₹7,999',
#  '₹5,499',
#  '₹9,999',
#  '₹13,990',
#  '₹8,999']

# %%
len(disc_price)
# Out:
# 24

# %%
avg_rating=[i.text for i in soup.find_all('div',{'class':'_3LWZlK'})]
avg_rating
# Out:
# ['4.3',
#  '4.5',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.1',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.4',
#  '3.7',
#  '4.4',
#  '4.3',
#  '4',
#  '5',
#  '4.4',
#  '5',
#  '5',
#  '4.5',
#  '4',
#  '3',
#  '4.3',
#  '4',
#  '5',
#  '4.4',
#  '4',
#  '1']

# %%
len(avg_rating)# here comes the problem
# Out:
# 39

# %%
results_page=soup.find_all('div',{'class':'_1YokD2 _3Mn1Gg'})[1]#becoz it shows length 2
results_page
# Out:
# <div class="_1YokD2 _3Mn1Gg" style="flex-grow:1;overflow:auto"><div class="_1YokD2 _2GoDe3 col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="_1AtVbE" style="flex-grow:1;overflow:auto"><div class="W_R1IA"><div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">Mobiles &amp; Accessories</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">Mobiles</a><svg clas
# ...

# %%
len(results_page)
# Out:
# 27

# %%
titles=[i.text for i in results_page.find_all('div',{'class':'_4rR01T'})]

# %%
titles
# Out:
# ['realme C20 (Cool Grey, 32 GB)',
#  'realme C21 (Cross Blue, 32 GB)',
#  'realme C21 (Cross Black, 32 GB)',
#  'realme C21 (Cross Black, 64 GB)',
#  'realme C21 (Cross Blue, 64 GB)',
#  'REDMI 9i (Midnight Black, 64 GB)',
#  'POCO M3 (Power Black, 64 GB)',
#  'realme Narzo 30A (Laser Black, 32 GB)',
#  'realme Narzo 30A (Laser Blue, 32 GB)',
#  'realme Narzo 30A (Laser Black, 64 GB)',
#  'POCO M3 (Cool Blue, 64 GB)',
#  'Infinix Smart 5 (Aegean Blue, 32 GB)',
#  'Infinix Smart 5 (7° Purple, 32 GB)',
#  'Infinix Smart 5 (Morandi Green, 32 GB)',
#  'Infinix Smart 5 (Obsidian Black, 32 GB)',
#  'GIONEE Max (Red, 32 GB)',
#  'realme C12 (Power Silver, 32 GB)',
#  'realme C12 (Power Blue, 32 GB)',
#  'REDMI 9 Power (Electric Green, 64 GB)',
#  'REDMI 9i (Nature Green, 64 GB)',
#  'GIONEE Max (Black, 32 GB)',
#  'realme C25 (Watery Blue, 64 GB)',
#  'LG W41 Pro (Laser Blue, 128 GB)',
#  'Infinix Hot 10 (Moonlight Jade, 64 GB)']

# %%
len(titles)
# Out:
# 24

# %%
avg_rating=[i.text for i in results_page.find_all('div',{'class':'_3LWZlK'})]
avg_rating
# Out:
# ['4.3',
#  '4.5',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.1',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.1',
#  '4.4',
#  '3.7',
#  '4.4']

# %%
len(avg_rating)
# Out:
# 24

# %%
disc_price=[i.text for i in results_page.find_all('div',{'class':'_30jeq3 _1_WHN1'})]
disc_price
# Out:
# ['₹6,799',
#  '₹7,999',
#  '₹7,999',
#  '₹8,999',
#  '₹8,999',
#  '₹7,999',
#  '₹10,999',
#  '₹7,999',
#  '₹7,999',
#  '₹8,999',
#  '₹10,999',
#  '₹6,799',
#  '₹6,799',
#  '₹6,799',
#  '₹6,799',
#  '₹5,499',
#  '₹7,999',
#  '₹7,999',
#  '₹10,499',
#  '₹7,999',
#  '₹5,499',
#  '₹9,999',
#  '₹13,990',
#  '₹8,999']

# %%
len(disc_price)
# Out:
# 24

# %%
totals=[i.text.split('\xa0&\xa0') for i in results_page.find_all('span',{'class':'_2_R_DZ'})]

# %%
totals
# Out:
# [['38,654 Ratings', '1,840 Reviews'],
#  ['20,734 Ratings', '937 Reviews'],
#  ['20,734 Ratings', '937 Reviews'],
#  ['18,590 Ratings', '809 Reviews'],
#  ['18,590 Ratings', '809 Reviews'],
#  ['3,14,402 Ratings', '17,869 Reviews'],
#  ['1,70,993 Ratings', '12,703 Reviews'],
#  ['47,585 Ratings', '3,364 Reviews'],
#  ['47,585 Ratings', '3,364 Reviews'],
#  ['73,725 Ratings', '4,678 Reviews'],
#  ['1,70,993 Ratings', '12,703 Reviews'],
#  ['22,036 Ratings', '1,710 Reviews'],
#  ['22,036 Ratings', '1,710 Reviews'],
#  ['22,036 Ratings', '1,710 Reviews'],
#  ['22,036 Ratings', '1,710 Reviews'],
#  ['77,611 Ratings', '7,467 Reviews'],
#  ['2,89,248 Ratings', '17,840 Reviews'],
#  ['2,89,248 Ratings', '17,840 Reviews'],
#  ['63,622 Ratings', '4,515 Reviews'],
#  ['3,14,402 Ratings', '17,869 Reviews'],
#  ['77,611 Ratings', '7,467 Reviews'],
#  ['21,863 Ratings', '947 Reviews'],
#  ['2,440 Ratings', '243 Reviews'],
#  ['63,849 Ratings', '5,122 Reviews']]

# %%
features=[i.text for i in results_page.find_all('ul',{'class':'_1xgFaf'})]

# %%
features
# Out:
# ['2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display8MP Rear Camera | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '3 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '3 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({'titles':titles,'price':disc_price,'avg_rating':avg_rating})

# %%
df
# Out:
#                                      titles    price avg_rating
# 0             realme C20 (Cool Grey, 32 GB)   ₹6,799        4.3
# 1            realme C21 (Cross Blue, 32 GB)   ₹7,999        4.5
# 2           realme C21 (Cross Black, 32 GB)   ₹7,999        4.5
# 3           realme C21 (Cross Black, 64 GB)   ₹8,999        4.4
# 4            realme C21 (Cross Blue, 64 GB)   ₹8,999        4.4
# 5          REDMI 9i (Midnight Black, 64 GB)   ₹7,999        4.3
# 6              POCO M3 (Power Black, 64 GB)  ₹10,999        4.3
# 7     realme Narzo 30A (Laser Black, 32 GB)   ₹7,999        4.4
# 8      realme Narzo 30A (Laser Blue, 32 GB)   ₹7,999        4.4
# 9     realme Narzo 30A (Laser Black, 64 GB)   ₹8,999        4.4
# 10               POCO M3 (Cool Blue, 64 GB)  ₹10,999        4.3
# 11     Infinix Smart 5 (Aegean Blue, 32 GB)   ₹6,799        4.4
# 12       Infinix Smart 5 (7° Purple, 32 GB)   ₹6,799        4.4
# 13   Infinix Smart 5 (Morandi Green, 32 GB)   ₹6,799        4.4
# ...
